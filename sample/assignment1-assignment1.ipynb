# %% [markdown]
# # Assignment 1
# Before you start working on the problems, here is a small example to help you understand how to write your answers. The solution should be written within the function body given, and the final result should be returned. Then the autograder will try to call the function and validate your returned result accordingly. Before submitting to the autograder, see if the tests we have included with this file pass by pressing the *Validate* button on the toolbar.
#
# **Note: For all assignments please write all of your code within the function we define in order to ensure it is run by the autograder correctly**

# %%
def example_word_count():
    # This example question requires counting words in the example_string below.
    example_string = "Amy is 5 years old"

    # You should fix the given code only between ### FIX CODE BELOW and ### FIX CODE ABOVE. 
    # Your code should return a result. 
    # You can comment out or delete the NotImplementedError below.
    
    ### FIX CODE BELOW 
    result = example_string.split(" ")
    ### FIX CODE ABOVE
    #raise NotImplementedError()
    return len(result)

# %% [markdown]
# ## Question 1: names()
#
# Fix the incorrect regex between `### FIX CODE BELOW` and `### FIX CODE ABOVE` to generate a list of names in the simple_string.

# %%
def names():
    import re
    simple_string = """Amy is 5 years old, and her sister Mary is 2 years old. 
    Ruth and Peter, their parents, have 3 kids."""

    ### FIX CODE BELOW  
    pattern = r'([A-Z]([a-z])*)'
    match = re.findall(pattern, simple_string)
    ### FIX CODE ABOVE  
    
    # YOUR CODE HERE
    names = []
    for i in match:
        names.append(i[0])
        
       
    
    return names
    
names()
# Out:
# ['Amy', 'Mary', 'Ruth', 'Peter']

# %%
assert len(names()) == 4, "There are four names in the simple_string"

# %% [markdown]
# ## Question 2: student_grades()
#
# The dataset file in [assets/grades.txt](assets/grades.txt) contains multiple lines of people along with their grades in a class. Fix the incorrect regex between `### FIX CODE BELOW` and `### FIX CODE ABOVE` to generate a list of just those students who received a B in the course (e.g., \[\'John Doe\', \'Jane Doe\'\].)

# %%
def student_grades():
    import re
    with open ("assets/grades.txt", "r") as file:
        grades = file.read()

    ### FIX CODE BELOW
    pattern = r'([A-Z][a-z]+ [A-Z][a-z]+): B'
    matches = re.findall(pattern,grades)
    ### FIX CODE ABOVE
        
    grades = []
    for i in matches:
        grades.append(i)
        
    # YOUR CODE HERE
  

    return grades 
    
student_grades()
# Out:
# ['Bell Kassulke',
#  'Simon Loidl',
#  'Elias Jovanovic',
#  'Hakim Botros',
#  'Emilie Lorentsen',
#  'Jake Wood',
#  'Fatemeh Akhtar',
#  'Kim Weston',
#  'Yasmin Dar',
#  'Viswamitra Upandhye',
#  'Killian Kaufman',
#  'Elwood Page',
#  'Elodie Booker',
#  'Adnan Chen',
#  'Hank Spinka',
#  'Hannah Bayer']

# %%
assert len(student_grades()) == 16

### BEGIN HIDDEN TESTS

name_list = ['Bell Kassulke',
 'Simon Loidl',
 'Elias Jovanovic',
 'Hakim Botros',
 'Emilie Lorentsen',
 'Jake Wood',
 'Fatemeh Akhtar',
 'Kim Weston',
 'Yasmin Dar',
 'Viswamitra Upandhye',
 'Killian Kaufman',
 'Elwood Page',
 'Elodie Booker',
 'Adnan Chen',
 'Hank Spinka',
 'Hannah Bayer']

assert (': B' in student_grades()[1]) == False, "Please only return student names."
assert ('Kassulke' in student_grades()) == False, "Please return students' full name."
for name in name_list:
    assert (name in student_grades())== True, "Check your name list."

### END HIDDEN TESTS

# %% [markdown]
# ## Question 3: logs()
# Consider the variable 'logdata' which is a string containing a standard web log. This variable records the access a user makes when visiting a web page (like this one!). Each line of the log has the following items:
#
# * a host (e.g., ‘146.204.224.152’)
# * a username (e.g., ‘feest6811’ or sometime '-' since it is missing)
# * the time a request was made (e.g., ‘21/Jun/2019:15:45:24 -0700’)
# * the post request type (e.g., ‘POST /incentivize HTTP/1.1’)
#
# Your task is to fix the incorrect regex between `### FIX CODE BELOW` and `### FIX CODE ABOVE` to convert the given data into a list of dictionaries, where each dictionary looks like the following:
#
# ```
# example_dict = {"host":"146.204.224.152",
#                 "user_name":"feest6811",
#                 "time":"21/Jun/2019:15:45:24 -0700",
#                 "request":"POST /incentivize HTTP/1.1"}
# ```

# %%
def logs():
    import re
    with open("assets/logdata.txt", "r") as file:
        logdata = file.read()
    
        
    ### FIX CODE BELOW    
    pattern = "(?P<host>[0-9]+[.][0-9]+[.][0-9]+[.][0-9]+) (-) (?P<name>[a-z]+[0-9]*) (?P<time>[[0-9]*/[A-Z]+[a-z]*/[0-9]*:[0-9]+:[0-9]*:[0-9]* -[0-9]*]) (?P<request>\"[A-Z]* (.+?) (.+?)) "

    logs = []
    ### FIX CODE ABOVE

    for i in re.finditer(pattern, logdata):
        logs.append(i.groupdict())

    # YOUR CODE HERE

    return logs

logs()
# Out:
# /var/folders/cn/99ljq6px1x38m44wlngkn3900000gn/T/ipykernel_61971/3921157383.py:12: FutureWarning: Possible nested set at position 81
#   for i in re.finditer(pattern, logdata):
# [{'host': '146.204.224.152',
#   'name': 'feest6811',
#   'time': '[21/Jun/2019:15:45:24 -0700]',
#   'request': '"POST /incentivize HTTP/1.1"'},
#  {'host': '197.109.77.178',
#   'name': 'kertzmann3129',
#   'time': '[21/Jun/2019:15:45:25 -0700]',
#   'request': '"DELETE /virtual/solutions/target/web+services HTTP/2.0"'},
#  {'host': '156.127.178.177',
#   'name': 'okuneva5222',
#   'time': '[21/Jun/2019:15:45:27 -0700]',
#   'request': '"DELETE /interactive/transparent/niches/revolutionize HTTP/1.1"'},
#  {'host': '100.32.205.59',
#   'name': 'ortiz8891',
#   'time': '[21/Jun/2019:15:45:28 -0700]',
#   'request': '"PATCH /architectures HTTP/1.0"'},
#  {'host': '168.95.156.240',
#   'name': 'stark2413',
#   'time': '[21/Jun/2019:15:45:31 -0700]',
#   'request': '"GET /engage HTTP/2.0"'},
#  {'host': '71.172.239.195',
#   'name': 'dooley1853',
#   'time': '[21/Jun/2019:15:45:32 -0700]',
#   'request': '"PUT /cutting-edge HTTP/2.0"'},
#  {'host': '180.95.121.94',
#   'name': 'mohr6893',
#   'time': '[21/Jun/2019:15:45:34 -0700]',
#   'request': '"PATCH /extensible/reinvent HTTP/1.1"'},
#  {'host': '144.23.247.108',
#   'name': 'auer7552',
#   'time': '[21/Jun/2019:15:45:35 -0700]',
#   'request': '"POST /extensible/infrastructures/one-to-one/enterprise HTTP/1.1"'},
#  {'host': '2.179.103.97',
#   'name': 'lind8584',
#   'time': '[21/Jun/2019:15:45:36 -0700]',
#   'request': '"POST /grow/front-end/e-commerce/robust HTTP/2.0"'},
#  {'host': '241.114.184.133',
#   'name': 'tromp8355',
#   'time': '[21/Jun/2019:15:45:37 -0700]',
#   'request': '"GET /redefine/orchestrate HTTP/1.0"'},
#  {'host': '224.188.38.4',
#   'name': 'keebler1423',
#   'time': '[21/Jun/2019:15:45:40 -0700]',
#   'request': '"PUT /orchestrate/out-of-the-box/unleash/syndicate HTTP/1.1"'},
#  {'host': '94.11.36.112',
#   'name': 'klein8508',
#   'time': '[21/Jun/2019:15:45:41 -0700]',
#   'request': '"POST /enhance/solutions/bricks-and-clicks HTTP/1.1"'},
#  {'host': '126.196.238.197',
#   'name': 'gusikowski9864',
#   'time': '[21/Jun/2019:15:45:45 -0700]',
#   'request': '"DELETE /rich/reinvent HTTP/2.0"'},
#  {'host': '103.247.168.212',
#   'name': 'medhurst2732',
#   'time': '[21/Jun/2019:15:45:49 -0700]',
#   'request': '"HEAD /scale/global/leverage HTTP/1.0"'},
#  {'host': '57.86.153.68',
#   'name': 'dubuque8645',
#   'time': '[21/Jun/2019:15:45:50 -0700]',
#   'request': '"POST /innovative/roi/robust/systems HTTP/1.1"'},
#  {'host': '231.220.8.214',
#   'name': 'luettgen1860',
#   'time': '[21/Jun/2019:15:45:52 -0700]',
#   'request': '"HEAD /systems/sexy HTTP/1.1"'},
#  {'host': '219.133.7.154',
#   'name': 'price5585',
#   'time': '[21/Jun/2019:15:45:53 -0700]',
#   'request': '"GET /incubate/incubate HTTP/1.1"'},
#  {'host': '159.252.184.44',
#   'name': 'fay7852',
#   'time': '[21/Jun/2019:15:45:54 -0700]',
#   'request': '"GET /convergence HTTP/2.0"'},
#  {'host': '40.167.172.66',
#   'name': 'kshlerin3090',
#   'time': '[21/Jun/2019:15:45:57 -0700]',
#   'request': '"HEAD /convergence HTTP/2.0"'},
#  {'host': '167.153.239.72',
#   'name': 'schaden8853',
#   'time': '[21/Jun/2019:15:45:58 -0700]',
#   'request': '"DELETE /bandwidth/reintermediate/engage HTTP/2.0"'},
#  {'host': '115.214.173.248',
#   'name': 'hauck8214',
#   'time': '[21/Jun/2019:15:46:00 -0700]',
#   'request': '"PUT /optimize HTTP/1.1"'},
#  {'host': '21.43.188.186',
#   'name': 'kunze2653',
#   'time': '[21/Jun/2019:15:46:02 -0700]',
#   'request': '"DELETE /bandwidth/turn-key/users HTTP/2.0"'},
#  {'host': '86.187.99.249',
#   'name': 'tillman6650',
#   'time': '[21/Jun/2019:15:46:03 -0700]',
#   'request': '"POST /efficient/unleash HTTP/1.1"'},
#  {'host': '76.72.133.93',
#   'name': 'carroll1056',
#   'time': '[21/Jun/2019:15:46:05 -0700]',
#   'request': '"POST /morph/optimize/plug-and-play HTTP/2.0"'},
#  {'host': '73.162.151.229',
#   'name': 'dubuque3528',
#   'time': '[21/Jun/2019:15:46:08 -0700]',
#   'request': '"DELETE /transition/holistic/e-business HTTP/2.0"'},
#  {'host': '13.112.8.80',
#   'name': 'rau5026',
#   'time': '[21/Jun/2019:15:46:09 -0700]',
#   'request': '"HEAD /ubiquitous/transparent HTTP/1.1"'},
#  {'host': '136.195.158.6',
#   'name': 'feeney9464',
#   'time': '[21/Jun/2019:15:46:11 -0700]',
#   'request': '"HEAD /open-source/markets HTTP/2.0"'},
#  {'host': '59.101.239.174',
#   'name': 'brekke3293',
#   'time': '[21/Jun/2019:15:46:13 -0700]',
#   'request': '"DELETE /ubiquitous/seize/web-enabled HTTP/2.0"'},
#  {'host': '62.79.96.179',
#   'name': 'mayer1069',
#   'time': '[21/Jun/2019:15:46:15 -0700]',
#   'request': '"HEAD /facilitate HTTP/1.0"'},
#  {'host': '217.70.194.150',
#   'name': 'batz2602',
#   'time': '[21/Jun/2019:15:46:16 -0700]',
#   'request': '"PUT /functionalities/channels/productize/mission-critical HTTP/2.0"'},
#  {'host': '11.57.203.39',
#   'name': 'carroll8889',
#   'time': '[21/Jun/2019:15:46:21 -0700]',
#   'request': '"HEAD /visionary/cultivate HTTP/1.1"'},
#  {'host': '203.36.55.39',
#   'name': 'collins6322',
#   'time': '[21/Jun/2019:15:46:23 -0700]',
#   'request': '"PATCH /efficient/productize/disintermediate HTTP/1.1"'},
#  {'host': '87.234.209.125',
#   'name': 'labadie6990',
#   'time': '[21/Jun/2019:15:46:26 -0700]',
#   'request': '"GET /unleash/aggregate HTTP/2.0"'},
#  {'host': '177.164.9.130',
#   'name': 'collins9387',
#   'time': '[21/Jun/2019:15:46:27 -0700]',
#   'request': '"DELETE /portals/evolve/proactive HTTP/1.0"'},
#  {'host': '161.106.82.60',
#   'name': 'yundt9152',
#   'time': '[21/Jun/2019:15:46:29 -0700]',
#   'request': '"PUT /e-tailers HTTP/1.1"'},
#  {'host': '226.97.226.58',
#   'name': 'kautzer4542',
#   'time': '[21/Jun/2019:15:46:31 -0700]',
#   'request': '"PATCH /functionalities/convergence/repurpose/reinvent HTTP/1.1"'},
#  {'host': '180.234.185.134',
#   'name': 'windler5463',
#   'time': '[21/Jun/2019:15:46:34 -0700]',
#   'request': '"POST /synergies/innovative/enterprise HTTP/1.1"'},
#  {'host': '130.240.69.236',
#   'name': 'hoeger9514',
#   'time': '[21/Jun/2019:15:46:36 -0700]',
#   'request': '"PUT /drive HTTP/2.0"'},
#  {'host': '226.187.228.119',
#   'name': 'bednar5295',
#   'time': '[21/Jun/2019:15:46:37 -0700]',
#   'request': '"HEAD /streamline/metrics/visionary/deliverables HTTP/1.1"'},
#  {'host': '169.191.251.30',
#   'name': 'champlin3406',
#   'time': '[21/Jun/2019:15:46:38 -0700]',
#   'request': '"PUT /out-of-the-box/value-added/engineer HTTP/2.0"'},
#  {'host': '33.212.159.241',
#   'name': 'kertzmann4700',
#   'time': '[21/Jun/2019:15:46:39 -0700]',
#   'request': '"HEAD /evolve/drive/transition HTTP/1.1"'},
#  {'host': '151.2.27.136',
#   'name': 'kunde3872',
#   'time': '[21/Jun/2019:15:46:40 -0700]',
#   'request': '"HEAD /monetize HTTP/1.1"'},
#  {'host': '230.72.69.136',
#   'name': 'quitzon6990',
#   'time': '[21/Jun/2019:15:46:42 -0700]',
#   'request': '"POST /channels HTTP/1.1"'},
#  {'host': '189.128.147.107',
#   'name': 'johnson1417',
#   'time': '[21/Jun/2019:15:46:43 -0700]',
#   'request': '"PUT /synergize/innovative HTTP/1.0"'},
#  {'host': '98.74.141.240',
#   'name': 'terry3353',
#   'time': '[21/Jun/2019:15:46:46 -0700]',
#   'request': '"GET /paradigms/reintermediate/web-enabled HTTP/1.1"'},
#  {'host': '249.157.76.12',
#   'name': 'doyle8092',
#   'time': '[21/Jun/2019:15:46:47 -0700]',
#   'request': '"HEAD /end-to-end/open-source/markets HTTP/1.0"'},
#  {'host': '191.83.194.6',
#   'name': 'tillman4353',
#   'time': '[21/Jun/2019:15:46:48 -0700]',
#   'request': '"PATCH /frictionless/evolve/methodologies HTTP/1.1"'},
#  {'host': '28.251.116.209',
#   'name': 'wuckert7686',
#   'time': '[21/Jun/2019:15:46:50 -0700]',
#   'request': '"DELETE /productize/maximize HTTP/1.1"'},
#  {'host': '113.136.44.97',
#   'name': 'schinner1581',
#   'time': '[21/Jun/2019:15:46:52 -0700]',
#   'request': '"HEAD /intuitive/communities/maximize/repurpose HTTP/1.1"'},
#  {'host': '148.185.136.238',
#   'name': 'will3148',
#   'time': '[21/Jun/2019:15:46:54 -0700]',
#   'request': '"PUT /interactive/target HTTP/1.0"'},
#  {'host': '192.57.65.185',
#   'name': 'beatty2311',
#   'time': '[21/Jun/2019:15:46:56 -0700]',
#   'request': '"GET /customized/incentivize HTTP/2.0"'},
#  {'host': '174.36.25.145',
#   'name': 'reinger5141',
#   'time': '[21/Jun/2019:15:46:58 -0700]',
#   'request': '"GET /e-business/reintermediate/magnetic HTTP/1.1"'},
#  {'host': '109.108.118.102',
#   'name': 'greenfelder4613',
#   'time': '[21/Jun/2019:15:46:59 -0700]',
#   'request': '"PUT /networks/strategize/b2c HTTP/2.0"'},
#  {'host': '207.93.9.141',
#   'name': 'kulas9437',
#   'time': '[21/Jun/2019:15:47:00 -0700]',
#   'request': '"PATCH /user-centric HTTP/2.0"'},
#  {'host': '23.48.88.246',
#   'name': 'boyer9465',
#   'time': '[21/Jun/2019:15:47:01 -0700]',
#   'request': '"PUT /global/collaborative/synthesize HTTP/1.0"'},
#  {'host': '199.111.169.6',
#   'name': 'jaskolski5282',
#   'time': '[21/Jun/2019:15:47:09 -0700]',
#   'request': '"PUT /distributed/eyeballs/value-added/unleash HTTP/1.1"'},
#  {'host': '21.24.38.93',
#   'name': 'roob7248',
#   'time': '[21/Jun/2019:15:47:10 -0700]',
#   'request': '"DELETE /synergistic HTTP/1.1"'},
#  {'host': '121.104.130.220',
#   'name': 'dach6856',
#   'time': '[21/Jun/2019:15:47:11 -0700]',
#   'request': '"GET /infomediaries/e-business/metrics/interfaces HTTP/1.0"'},
#  {'host': '91.107.45.211',
#   'name': 'roob7504',
#   'time': '[21/Jun/2019:15:47:13 -0700]',
#   'request': '"POST /transparent/one-to-one HTTP/1.0"'},
#  {'host': '105.8.97.99',
#   'name': 'nader4497',
#   'time': '[21/Jun/2019:15:47:15 -0700]',
#   'request': '"PATCH /repurpose/b2b HTTP/1.0"'},
#  {'host': '92.176.179.73',
#   'name': 'tromp7323',
#   'time': '[21/Jun/2019:15:47:16 -0700]',
#   'request': '"POST /web+services/monetize/infomediaries HTTP/1.0"'},
#  {'host': '124.113.245.136',
#   'name': 'koch7592',
#   'time': '[21/Jun/2019:15:47:17 -0700]',
#   'request': '"PATCH /interfaces/portals HTTP/1.1"'},
#  {'host': '153.207.83.135',
#   'name': 'fritsch7933',
#   'time': '[21/Jun/2019:15:47:18 -0700]',
#   'request': '"POST /exploit/methodologies/proactive/paradigms HTTP/1.0"'},
#  {'host': '210.99.35.196',
#   'name': 'nitzsche6699',
#   'time': '[21/Jun/2019:15:47:20 -0700]',
#   'request': '"DELETE /wireless HTTP/1.1"'},
#  {'host': '245.247.95.68',
#   'name': 'cummerata3376',
#   'time': '[21/Jun/2019:15:47:24 -0700]',
#   'request': '"GET /redefine HTTP/2.0"'},
#  {'host': '203.217.133.243',
#   'name': 'gislason8036',
#   'time': '[21/Jun/2019:15:47:25 -0700]',
#   'request': '"POST /visualize/incubate HTTP/1.0"'},
#  {'host': '183.199.215.84',
#   'name': 'homenick3730',
#   'time': '[21/Jun/2019:15:47:26 -0700]',
#   'request': '"POST /infrastructures/rich HTTP/2.0"'},
#  {'host': '82.207.85.184',
#   'name': 'hansen5317',
#   'time': '[21/Jun/2019:15:47:27 -0700]',
#   'request': '"POST /initiatives/vertical/leading-edge HTTP/2.0"'},
#  {'host': '22.135.157.6',
#   'name': 'runolfsdottir9957',
#   'time': '[21/Jun/2019:15:47:29 -0700]',
#   'request': '"PUT /synergies/b2c HTTP/1.1"'},
#  {'host': '34.185.208.17',
#   'name': 'wilderman1726',
#   'time': '[21/Jun/2019:15:47:30 -0700]',
#   'request': '"DELETE /e-enable/granular/scale HTTP/2.0"'},
#  {'host': '147.106.164.197',
#   'name': 'huels5802',
#   'time': '[21/Jun/2019:15:47:31 -0700]',
#   'request': '"PATCH /communities/cultivate HTTP/1.1"'},
#  {'host': '237.149.195.234',
#   'name': 'powlowski8494',
#   'time': '[21/Jun/2019:15:47:32 -0700]',
#   'request': '"PATCH /productize HTTP/2.0"'},
#  {'host': '10.180.30.149',
#   'name': 'farrell3121',
#   'time': '[21/Jun/2019:15:47:33 -0700]',
#   'request': '"HEAD /vertical/schemas/rich/bandwidth HTTP/1.1"'},
#  {'host': '223.244.102.20',
#   'name': 'kozey1688',
#   'time': '[21/Jun/2019:15:47:35 -0700]',
#   'request': '"HEAD /rich/models/user-centric/synergize HTTP/1.0"'},
#  {'host': '247.173.105.48',
#   'name': 'mosciski4497',
#   'time': '[21/Jun/2019:15:47:37 -0700]',
#   'request': '"GET /visualize HTTP/1.0"'},
#  {'host': '48.17.245.135',
#   'name': 'thompson4253',
#   'time': '[21/Jun/2019:15:47:38 -0700]',
#   'request': '"HEAD /dynamic HTTP/1.1"'},
#  {'host': '147.226.217.25',
#   'name': 'stark2160',
#   'time': '[21/Jun/2019:15:47:40 -0700]',
#   'request': '"GET /synergistic/utilize HTTP/1.0"'},
#  {'host': '225.65.31.51',
#   'name': 'koss1626',
#   'time': '[21/Jun/2019:15:47:43 -0700]',
#   'request': '"DELETE /frictionless/transparent/extensible/revolutionary HTTP/1.1"'},
#  {'host': '137.121.171.78',
#   'name': 'mckenzie9789',
#   'time': '[21/Jun/2019:15:47:45 -0700]',
#   'request': '"DELETE /seize/global HTTP/1.0"'},
#  {'host': '130.219.221.187',
#   'name': 'auer9353',
#   'time': '[21/Jun/2019:15:47:46 -0700]',
#   'request': '"GET /interactive/real-time/target HTTP/2.0"'},
#  {'host': '49.195.132.6',
#   'name': 'collins9784',
#   'time': '[21/Jun/2019:15:47:49 -0700]',
#   'request': '"DELETE /bricks-and-clicks/recontextualize/seize HTTP/2.0"'},
#  {'host': '233.53.164.32',
#   'name': 'maggio9908',
#   'time': '[21/Jun/2019:15:47:50 -0700]',
#   'request': '"POST /global/channels/cross-media HTTP/1.1"'},
#  {'host': '124.10.38.5',
#   'name': 'hickle4568',
#   'time': '[21/Jun/2019:15:47:52 -0700]',
#   'request': '"HEAD /bandwidth/users/morph HTTP/1.0"'},
#  {'host': '141.59.150.229',
#   'name': 'tremblay7489',
#   'time': '[21/Jun/2019:15:47:54 -0700]',
#   'request': '"DELETE /platforms/maximize/interfaces/clicks-and-mortar HTTP/2.0"'},
#  {'host': '31.215.24.55',
#   'name': 'pfeffer6357',
#   'time': '[21/Jun/2019:15:47:56 -0700]',
#   'request': '"HEAD /engage/magnetic HTTP/2.0"'},
#  {'host': '148.137.75.120',
#   'name': 'gibson4540',
#   'time': '[21/Jun/2019:15:47:57 -0700]',
#   'request': '"HEAD /b2b HTTP/2.0"'},
#  {'host': '111.63.41.199',
#   'name': 'kirlin4598',
#   'time': '[21/Jun/2019:15:47:58 -0700]',
#   'request': '"PUT /unleash/grow/models HTTP/2.0"'},
#  {'host': '106.80.125.72',
#   'name': 'nienow5906',
#   'time': '[21/Jun/2019:15:47:59 -0700]',
#   'request': '"GET /engineer/compelling/robust/infrastructures HTTP/1.0"'},
#  {'host': '65.42.94.224',
#   'name': 'wolff6881',
#   'time': '[21/Jun/2019:15:48:02 -0700]',
#   'request': '"POST /extend/empower HTTP/1.1"'},
#  {'host': '63.106.221.202',
#   'name': 'roberts8938',
#   'time': '[21/Jun/2019:15:48:05 -0700]',
#   'request': '"DELETE /reintermediate/envisioneer/innovative HTTP/1.1"'},
#  {'host': '66.233.63.11',
#   'name': 'yost2119',
#   'time': '[21/Jun/2019:15:48:09 -0700]',
#   'request': '"PATCH /out-of-the-box/action-items HTTP/1.0"'},
#  {'host': '44.103.233.51',
#   'name': 'krajcik9464',
#   'time': '[21/Jun/2019:15:48:10 -0700]',
#   'request': '"DELETE /portals/extend/methodologies/integrate HTTP/1.0"'},
#  {'host': '178.41.82.142',
#   'name': 'wuckert7752',
#   'time': '[21/Jun/2019:15:48:11 -0700]',
#   'request': '"DELETE /evolve/clicks-and-mortar/architect HTTP/1.1"'},
#  {'host': '27.213.87.112',
#   'name': 'kirlin4667',
#   'time': '[21/Jun/2019:15:48:12 -0700]',
#   'request': '"PUT /models/best-of-breed/bricks-and-clicks HTTP/2.0"'},
#  {'host': '65.113.165.7',
#   'name': 'nitzsche2796',
#   'time': '[21/Jun/2019:15:48:19 -0700]',
#   'request': '"DELETE /infomediaries/harness/expedite/orchestrate HTTP/2.0"'},
#  {'host': '223.75.102.252',
#   'name': 'zemlak4312',
#   'time': '[21/Jun/2019:15:48:20 -0700]',
#   'request': '"HEAD /e-tailers/sexy/extensible HTTP/1.0"'},
#  {'host': '83.12.28.227',
#   'name': 'nolan1426',
#   'time': '[21/Jun/2019:15:48:21 -0700]',
#   'request': '"DELETE /global/reintermediate HTTP/1.1"'},
#  {'host': '178.20.130.66',
#   'name': 'mayer2417',
#   'time': '[21/Jun/2019:15:48:23 -0700]',
#   'request': '"GET /transparent HTTP/1.0"'},
#  {'host': '93.61.70.250',
#   'name': 'cassin5420',
#   'time': '[21/Jun/2019:15:48:24 -0700]',
#   'request': '"DELETE /portals HTTP/1.0"'},
#  {'host': '77.5.250.80',
#   'name': 'bailey4806',
#   'time': '[21/Jun/2019:15:48:25 -0700]',
#   'request': '"DELETE /enhance/e-business/impactful HTTP/2.0"'},
#  {'host': '10.229.72.234',
#   'name': 'rogahn7487',
#   'time': '[21/Jun/2019:15:48:26 -0700]',
#   'request': '"GET /web-readiness HTTP/1.0"'},
#  {'host': '114.182.112.12',
#   'name': 'walter1917',
#   'time': '[21/Jun/2019:15:48:27 -0700]',
#   'request': '"PUT /deliverables/benchmark HTTP/1.0"'},
#  {'host': '197.35.190.56',
#   'name': 'cole1245',
#   'time': '[21/Jun/2019:15:48:28 -0700]',
#   'request': '"HEAD /whiteboard/bleeding-edge/disintermediate/cultivate HTTP/1.0"'},
#  {'host': '44.147.46.145',
#   'name': 'runolfsdottir2005',
#   'time': '[21/Jun/2019:15:48:31 -0700]',
#   'request': '"DELETE /web+services/reinvent/real-time/cross-media HTTP/1.0"'},
#  {'host': '197.185.253.55',
#   'name': 'cormier5217',
#   'time': '[21/Jun/2019:15:48:32 -0700]',
#   'request': '"PATCH /dynamic/eyeballs/incentivize HTTP/2.0"'},
#  {'host': '116.132.156.28',
#   'name': 'emard5518',
#   'time': '[21/Jun/2019:15:48:35 -0700]',
#   'request': '"GET /robust/efficient/sticky/robust HTTP/2.0"'},
#  {'host': '46.94.236.10',
#   'name': 'jacobi6125',
#   'time': '[21/Jun/2019:15:48:36 -0700]',
#   'request': '"GET /mindshare/e-services/action-items HTTP/1.1"'},
#  {'host': '196.16.205.128',
#   'name': 'stanton2862',
#   'time': '[21/Jun/2019:15:48:37 -0700]',
#   'request': '"DELETE /recontextualize HTTP/1.1"'},
#  {'host': '65.160.59.55',
#   'name': 'ortiz2311',
#   'time': '[21/Jun/2019:15:48:38 -0700]',
#   'request': '"HEAD /interactive/integrated/incentivize HTTP/1.1"'},
#  {'host': '107.253.103.62',
#   'name': 'maggio7837',
#   'time': '[21/Jun/2019:15:48:39 -0700]',
#   'request': '"GET /infomediaries HTTP/1.1"'},
#  {'host': '13.253.202.85',
#   'name': 'nader6495',
#   'time': '[21/Jun/2019:15:48:40 -0700]',
#   'request': '"HEAD /extend/scale/whiteboard HTTP/1.0"'},
#  {'host': '120.3.195.188',
#   'name': 'zboncak8896',
#   'time': '[21/Jun/2019:15:48:43 -0700]',
#   'request': '"HEAD /monetize/matrix/incentivize/paradigms HTTP/1.0"'},
#  {'host': '67.91.67.236',
#   'name': 'hammes1596',
#   'time': '[21/Jun/2019:15:48:47 -0700]',
#   'request': '"HEAD /models/enhance/streamline HTTP/2.0"'},
#  {'host': '159.5.202.167',
#   'name': 'moen9202',
#   'time': '[21/Jun/2019:15:48:53 -0700]',
#   'request': '"DELETE /technologies/schemas/methodologies/mission-critical HTTP/2.0"'},
#  {'host': '232.181.229.75',
#   'name': 'lehner6109',
#   'time': '[21/Jun/2019:15:48:55 -0700]',
#   'request': '"PUT /transition HTTP/1.1"'},
#  {'host': '254.88.251.245',
#   'name': 'nolan6998',
#   'time': '[21/Jun/2019:15:48:56 -0700]',
#   'request': '"DELETE /whiteboard HTTP/1.1"'},
#  {'host': '110.112.78.242',
#   'name': 'kling1525',
#   'time': '[21/Jun/2019:15:48:57 -0700]',
#   'request': '"POST /paradigms/integrated HTTP/1.1"'},
#  {'host': '116.55.22.122',
#   'name': 'bahringer5369',
#   'time': '[21/Jun/2019:15:48:58 -0700]',
#   'request': '"PATCH /compelling/disintermediate HTTP/1.1"'},
#  {'host': '172.124.11.171',
#   'name': 'quitzon1416',
#   'time': '[21/Jun/2019:15:48:59 -0700]',
#   'request': '"POST /out-of-the-box/roi/e-enable HTTP/1.0"'},
#  {'host': '210.255.229.144',
#   'name': 'moen2716',
#   'time': '[21/Jun/2019:15:49:02 -0700]',
#   'request': '"POST /end-to-end/applications HTTP/2.0"'},
#  {'host': '74.21.133.131',
#   'name': 'waters3612',
#   'time': '[21/Jun/2019:15:49:03 -0700]',
#   'request': '"GET /bleeding-edge/applications HTTP/2.0"'},
#  {'host': '134.190.123.28',
#   'name': 'braun2437',
#   'time': '[21/Jun/2019:15:49:05 -0700]',
#   'request': '"POST /extend/initiatives HTTP/2.0"'},
#  {'host': '145.131.76.133',
#   'name': 'kling3290',
#   'time': '[21/Jun/2019:15:49:06 -0700]',
#   'request': '"HEAD /e-business/holistic/mindshare/magnetic HTTP/2.0"'},
#  {'host': '215.214.69.146',
#   'name': 'kuhic1127',
#   'time': '[21/Jun/2019:15:49:07 -0700]',
#   'request': '"PATCH /holistic/exploit/transition HTTP/2.0"'},
#  {'host': '20.179.60.207',
#   'name': 'mcglynn3415',
#   'time': '[21/Jun/2019:15:49:10 -0700]',
#   'request': '"PUT /grow HTTP/2.0"'},
#  {'host': '217.60.55.82',
#   'name': 'boyer9211',
#   'time': '[21/Jun/2019:15:49:11 -0700]',
#   'request': '"GET /relationships/embrace/models HTTP/1.0"'},
#  {'host': '240.57.86.78',
#   'name': 'thompson7192',
#   'time': '[21/Jun/2019:15:49:14 -0700]',
#   'request': '"HEAD /strategic/strategic/open-source/maximize HTTP/1.0"'},
#  {'host': '164.128.154.124',
#   'name': 'effertz4240',
#   'time': '[21/Jun/2019:15:49:15 -0700]',
#   'request': '"PATCH /visualize/cross-platform/intuitive HTTP/1.1"'},
#  {'host': '219.150.27.76',
#   'name': 'reinger6377',
#   'time': '[21/Jun/2019:15:49:16 -0700]',
#   'request': '"GET /scale/grow/disintermediate/e-enable HTTP/2.0"'},
#  {'host': '218.100.131.71',
#   'name': 'leffler3986',
#   'time': '[21/Jun/2019:15:49:20 -0700]',
#   'request': '"PATCH /orchestrate/monetize/relationships HTTP/1.1"'},
#  {'host': '132.186.52.137',
#   'name': 'wunsch3097',
#   'time': '[21/Jun/2019:15:49:22 -0700]',
#   'request': '"DELETE /viral/eyeballs/brand HTTP/2.0"'},
#  {'host': '29.3.16.175',
#   'name': 'wolf7357',
#   'time': '[21/Jun/2019:15:49:24 -0700]',
#   'request': '"PUT /b2c HTTP/2.0"'},
#  {'host': '55.255.42.34',
#   'name': 'erdman7847',
#   'time': '[21/Jun/2019:15:49:25 -0700]',
#   'request': '"POST /one-to-one/viral/interfaces/embrace HTTP/1.0"'},
#  {'host': '244.32.122.180',
#   'name': 'shanahan9241',
#   'time': '[21/Jun/2019:15:49:27 -0700]',
#   'request': '"PATCH /cutting-edge HTTP/1.1"'},
#  {'host': '196.95.163.236',
#   'name': 'lockman1471',
#   'time': '[21/Jun/2019:15:49:28 -0700]',
#   'request': '"PATCH /niches/front-end/dot-com HTTP/1.0"'},
#  {'host': '165.157.86.133',
#   'name': 'runte2017',
#   'time': '[21/Jun/2019:15:49:29 -0700]',
#   'request': '"DELETE /grow/channels HTTP/1.0"'},
#  {'host': '187.240.183.141',
#   'name': 'sauer3376',
#   'time': '[21/Jun/2019:15:49:32 -0700]',
#   'request': '"DELETE /frictionless/platforms/networks HTTP/1.0"'},
#  {'host': '226.239.91.74',
#   'name': 'jakubowski4018',
#   'time': '[21/Jun/2019:15:49:33 -0700]',
#   'request': '"HEAD /vertical/models/cross-media/reintermediate HTTP/1.1"'},
#  {'host': '50.142.221.159',
#   'name': 'durgan7044',
#   'time': '[21/Jun/2019:15:49:38 -0700]',
#   'request': '"DELETE /one-to-one/experiences/content HTTP/1.1"'},
#  {'host': '153.86.38.119',
#   'name': 'gaylord9827',
#   'time': '[21/Jun/2019:15:49:40 -0700]',
#   'request': '"HEAD /drive/content/action-items HTTP/1.1"'},
#  {'host': '232.131.251.10',
#   'name': 'kutch1902',
#   'time': '[21/Jun/2019:15:49:42 -0700]',
#   'request': '"DELETE /disintermediate/benchmark/envisioneer HTTP/1.0"'},
#  {'host': '69.98.159.130',
#   'name': 'turner6424',
#   'time': '[21/Jun/2019:15:49:43 -0700]',
#   'request': '"PATCH /harness HTTP/2.0"'},
#  {'host': '223.182.232.174',
#   'name': 'maggio8143',
#   'time': '[21/Jun/2019:15:49:45 -0700]',
#   'request': '"PUT /embrace HTTP/2.0"'},
#  {'host': '191.118.123.46',
#   'name': 'simonis6976',
#   'time': '[21/Jun/2019:15:49:46 -0700]',
#   'request': '"PATCH /web-enabled/harness/transparent HTTP/1.0"'},
#  {'host': '206.163.96.216',
#   'name': 'buckridge3917',
#   'time': '[21/Jun/2019:15:49:48 -0700]',
#   'request': '"HEAD /transparent HTTP/2.0"'},
#  {'host': '163.27.80.92',
#   'name': 'monahan7718',
#   'time': '[21/Jun/2019:15:49:50 -0700]',
#   'request': '"POST /clicks-and-mortar/vortals HTTP/2.0"'},
#  {'host': '148.175.205.121',
#   'name': 'sipes2845',
#   'time': '[21/Jun/2019:15:49:51 -0700]',
#   'request': '"PATCH /brand/vertical/revolutionize/killer HTTP/1.0"'},
#  {'host': '199.88.191.4',
#   'name': 'breitenberg8163',
#   'time': '[21/Jun/2019:15:49:52 -0700]',
#   'request': '"PATCH /unleash HTTP/1.0"'},
#  {'host': '127.220.163.49',
#   'name': 'wisozk6703',
#   'time': '[21/Jun/2019:15:49:54 -0700]',
#   'request': '"PATCH /utilize HTTP/2.0"'},
#  {'host': '51.2.232.211',
#   'name': 'rutherford4378',
#   'time': '[21/Jun/2019:15:49:58 -0700]',
#   'request': '"POST /strategize/strategize/innovate HTTP/1.0"'},
#  {'host': '231.72.174.26',
#   'name': 'hills3866',
#   'time': '[21/Jun/2019:15:50:01 -0700]',
#   'request': '"POST /bleeding-edge/user-centric/embrace/wireless HTTP/1.1"'},
#  {'host': '41.208.246.19',
#   'name': 'jacobi7143',
#   'time': '[21/Jun/2019:15:50:03 -0700]',
#   'request': '"DELETE /e-enable HTTP/1.0"'},
#  {'host': '8.31.177.12',
#   'name': 'braun1922',
#   'time': '[21/Jun/2019:15:50:09 -0700]',
#   'request': '"PUT /transparent/niches HTTP/1.1"'},
#  {'host': '240.189.198.133',
#   'name': 'price7294',
#   'time': '[21/Jun/2019:15:50:12 -0700]',
#   'request': '"PATCH /b2b/24%2f365 HTTP/1.0"'},
#  {'host': '30.9.43.134',
#   'name': 'marvin4115',
#   'time': '[21/Jun/2019:15:50:13 -0700]',
#   'request': '"GET /front-end/mindshare/bandwidth/paradigms HTTP/1.0"'},
#  {'host': '88.211.3.111',
#   'name': 'turner9291',
#   'time': '[21/Jun/2019:15:50:14 -0700]',
#   'request': '"PATCH /networks/grow/exploit/proactive HTTP/1.1"'},
#  {'host': '208.45.172.73',
#   'name': 'vonrueden9811',
#   'time': '[21/Jun/2019:15:50:15 -0700]',
#   'request': '"POST /drive HTTP/1.0"'},
#  {'host': '143.194.39.107',
#   'name': 'anderson7046',
#   'time': '[21/Jun/2019:15:50:16 -0700]',
#   'request': '"HEAD /intuitive HTTP/1.1"'},
#  {'host': '157.163.234.192',
#   'name': 'stamm2348',
#   'time': '[21/Jun/2019:15:50:18 -0700]',
#   'request': '"PUT /e-business/web-readiness/grow HTTP/1.0"'},
#  {'host': '163.153.145.8',
#   'name': 'doyle2015',
#   'time': '[21/Jun/2019:15:50:21 -0700]',
#   'request': '"PUT /engineer HTTP/1.1"'},
#  {'host': '165.8.44.192',
#   'name': 'kemmer8421',
#   'time': '[21/Jun/2019:15:50:22 -0700]',
#   'request': '"HEAD /repurpose HTTP/1.0"'},
#  {'host': '178.84.242.98',
#   'name': 'dare5841',
#   'time': '[21/Jun/2019:15:50:24 -0700]',
#   'request': '"POST /synergies/enhance/repurpose HTTP/2.0"'},
#  {'host': '79.123.137.87',
#   'name': 'cassin8778',
#   'time': '[21/Jun/2019:15:50:26 -0700]',
#   'request': '"PATCH /e-markets/solutions/b2c/generate HTTP/2.0"'},
#  {'host': '49.118.219.8',
#   'name': 'koelpin5285',
#   'time': '[21/Jun/2019:15:50:30 -0700]',
#   'request': '"HEAD /collaborative/partnerships/aggregate HTTP/1.1"'},
#  {'host': '88.124.34.218',
#   'name': 'haag5592',
#   'time': '[21/Jun/2019:15:50:31 -0700]',
#   'request': '"PUT /turn-key/bleeding-edge HTTP/2.0"'},
#  {'host': '191.117.232.204',
#   'name': 'kohler4380',
#   'time': '[21/Jun/2019:15:50:32 -0700]',
#   'request': '"GET /enterprise HTTP/2.0"'},
#  {'host': '240.119.176.34',
#   'name': 'lubowitz6149',
#   'time': '[21/Jun/2019:15:50:33 -0700]',
#   'request': '"DELETE /systems/one-to-one HTTP/2.0"'},
#  {'host': '79.185.171.163',
#   'name': 'block1079',
#   'time': '[21/Jun/2019:15:50:40 -0700]',
#   'request': '"GET /repurpose/partnerships/bleeding-edge HTTP/2.0"'},
#  {'host': '156.58.195.56',
#   'name': 'bogisich7897',
#   'time': '[21/Jun/2019:15:50:42 -0700]',
#   'request': '"PUT /portals/deliverables HTTP/1.1"'},
#  {'host': '150.139.169.192',
#   'name': 'mann8285',
#   'time': '[21/Jun/2019:15:50:43 -0700]',
#   'request': '"PUT /e-business/bleeding-edge/optimize HTTP/1.0"'},
#  {'host': '184.246.41.227',
#   'name': 'mayert4085',
#   'time': '[21/Jun/2019:15:50:44 -0700]',
#   'request': '"GET /transition HTTP/2.0"'},
#  {'host': '202.6.77.154',
#   'name': 'thompson6002',
#   'time': '[21/Jun/2019:15:50:47 -0700]',
#   'request': '"HEAD /open-source/revolutionary/initiatives/dot-com HTTP/1.1"'},
#  {'host': '189.62.5.214',
#   'name': 'romaguera5473',
#   'time': '[21/Jun/2019:15:50:51 -0700]',
#   'request': '"DELETE /sticky HTTP/2.0"'},
#  {'host': '38.111.64.134',
#   'name': 'bins4571',
#   'time': '[21/Jun/2019:15:50:52 -0700]',
#   'request': '"HEAD /bricks-and-clicks HTTP/1.1"'},
#  {'host': '122.9.81.194',
#   'name': 'stoltenberg8660',
#   'time': '[21/Jun/2019:15:50:53 -0700]',
#   'request': '"PUT /convergence/global/vertical/engineer HTTP/1.1"'},
#  {'host': '7.205.75.72',
#   'name': 'west2407',
#   'time': '[21/Jun/2019:15:50:55 -0700]',
#   'request': '"GET /technologies HTTP/1.1"'},
#  {'host': '246.163.3.11',
#   'name': 'willms1885',
#   'time': '[21/Jun/2019:15:50:57 -0700]',
#   'request': '"DELETE /dot-com HTTP/1.0"'},
#  {'host': '23.6.200.51',
#   'name': 'marvin8479',
#   'time': '[21/Jun/2019:15:51:02 -0700]',
#   'request': '"PUT /maximize/utilize HTTP/1.1"'},
#  {'host': '87.56.184.191',
#   'name': 'funk5262',
#   'time': '[21/Jun/2019:15:51:03 -0700]',
#   'request': '"POST /scalable/integrated HTTP/1.0"'},
#  {'host': '96.76.27.126',
#   'name': 'haley9579',
#   'time': '[21/Jun/2019:15:51:05 -0700]',
#   'request': '"PATCH /visualize/web-enabled/enhance/synergize HTTP/1.0"'},
#  {'host': '130.181.59.232',
#   'name': 'towne3635',
#   'time': '[21/Jun/2019:15:51:06 -0700]',
#   'request': '"GET /dot-com/functionalities HTTP/1.1"'},
#  {'host': '165.111.167.225',
#   'name': 'gottlieb6924',
#   'time': '[21/Jun/2019:15:51:07 -0700]',
#   'request': '"PUT /envisioneer HTTP/1.1"'},
#  {'host': '223.170.242.159',
#   'name': 'okuneva8628',
#   'time': '[21/Jun/2019:15:51:08 -0700]',
#   'request': '"POST /enhance/cross-platform/interactive HTTP/2.0"'},
#  {'host': '202.162.118.175',
#   'name': 'greenholt5589',
#   'time': '[21/Jun/2019:15:51:09 -0700]',
#   'request': '"PATCH /maximize HTTP/1.1"'},
#  {'host': '230.220.15.38',
#   'name': 'gulgowski7868',
#   'time': '[21/Jun/2019:15:51:10 -0700]',
#   'request': '"DELETE /innovate/facilitate/users HTTP/1.0"'},
#  {'host': '33.26.188.200',
#   'name': 'raynor9337',
#   'time': '[21/Jun/2019:15:51:13 -0700]',
#   'request': '"POST /24%2f7 HTTP/2.0"'},
#  {'host': '211.17.216.102',
#   'name': 'kshlerin3121',
#   'time': '[21/Jun/2019:15:51:14 -0700]',
#   'request': '"DELETE /functionalities HTTP/1.1"'},
#  {'host': '93.153.48.201',
#   'name': 'cruickshank4469',
#   'time': '[21/Jun/2019:15:51:19 -0700]',
#   'request': '"GET /interactive/e-business/architect HTTP/2.0"'},
#  {'host': '228.203.34.179',
#   'name': 'bednar2337',
#   'time': '[21/Jun/2019:15:51:20 -0700]',
#   'request': '"HEAD /implement HTTP/1.0"'},
#  {'host': '66.198.80.221',
#   'name': 'ebert4690',
#   'time': '[21/Jun/2019:15:51:22 -0700]',
#   'request': '"PUT /leading-edge HTTP/1.0"'},
#  {'host': '127.251.49.55',
#   'name': 'bednar7249',
#   'time': '[21/Jun/2019:15:51:23 -0700]',
#   'request': '"PATCH /dynamic/engage/facilitate HTTP/1.1"'},
#  {'host': '67.232.93.92',
#   'name': 'borer9296',
#   'time': '[21/Jun/2019:15:51:24 -0700]',
#   'request': '"POST /cultivate HTTP/1.0"'},
#  {'host': '214.236.248.87',
#   'name': 'considine7686',
#   'time': '[21/Jun/2019:15:51:25 -0700]',
#   'request': '"PUT /repurpose/24%2f365 HTTP/2.0"'},
#  {'host': '23.52.106.162',
#   'name': 'hettinger9833',
#   'time': '[21/Jun/2019:15:51:27 -0700]',
#   'request': '"GET /leading-edge/24%2f365 HTTP/2.0"'},
#  {'host': '249.183.121.148',
#   'name': 'adams5230',
#   'time': '[21/Jun/2019:15:51:29 -0700]',
#   'request': '"PUT /world-class/models HTTP/1.1"'},
#  {'host': '16.56.50.149',
#   'name': 'friesen3358',
#   'time': '[21/Jun/2019:15:51:30 -0700]',
#   'request': '"GET /monetize/repurpose/infomediaries/infrastructures HTTP/2.0"'},
#  {'host': '246.181.246.57',
#   'name': 'hudson5809',
#   'time': '[21/Jun/2019:15:51:31 -0700]',
#   'request': '"PUT /transition/enhance/partnerships HTTP/2.0"'},
#  {'host': '199.251.34.231',
#   'name': 'kilback6840',
#   'time': '[21/Jun/2019:15:51:35 -0700]',
#   'request': '"PUT /24%2f365/granular/synergistic HTTP/2.0"'},
#  {'host': '39.95.201.29',
#   'name': 'dooley1637',
#   'time': '[21/Jun/2019:15:51:37 -0700]',
#   'request': '"DELETE /leading-edge HTTP/1.0"'},
#  {'host': '29.183.210.228',
#   'name': 'toy9491',
#   'time': '[21/Jun/2019:15:51:38 -0700]',
#   'request': '"DELETE /scale HTTP/1.0"'},
#  {'host': '111.64.171.65',
#   'name': 'stanton9204',
#   'time': '[21/Jun/2019:15:51:43 -0700]',
#   'request': '"PUT /cultivate HTTP/1.0"'},
#  {'host': '157.117.129.160',
#   'name': 'bogisich6895',
#   'time': '[21/Jun/2019:15:51:44 -0700]',
#   'request': '"PUT /open-source HTTP/2.0"'},
#  {'host': '232.117.182.116',
#   'name': 'conn7515',
#   'time': '[21/Jun/2019:15:51:45 -0700]',
#   'request': '"POST /empower/disintermediate/24%2f365 HTTP/1.0"'},
#  {'host': '174.174.210.5',
#   'name': 'funk5090',
#   'time': '[21/Jun/2019:15:51:46 -0700]',
#   'request': '"HEAD /intuitive HTTP/2.0"'},
#  {'host': '94.96.145.184',
#   'name': 'romaguera2467',
#   'time': '[21/Jun/2019:15:51:47 -0700]',
#   'request': '"DELETE /paradigms/reintermediate/e-services/cutting-edge HTTP/2.0"'},
#  {'host': '249.71.172.194',
#   'name': 'braun5844',
#   'time': '[21/Jun/2019:15:51:49 -0700]',
#   'request': '"PUT /unleash/enterprise/optimize HTTP/2.0"'},
#  {'host': '164.195.121.133',
#   'name': 'kutch2379',
#   'time': '[21/Jun/2019:15:51:50 -0700]',
#   'request': '"HEAD /maximize/back-end/metrics HTTP/1.0"'},
#  {'host': '228.173.203.108',
#   'name': 'harvey5371',
#   'time': '[21/Jun/2019:15:51:51 -0700]',
#   'request': '"POST /eyeballs/back-end/platforms HTTP/1.0"'},
#  {'host': '108.75.3.212',
#   'name': 'cummings7077',
#   'time': '[21/Jun/2019:15:51:54 -0700]',
#   'request': '"PATCH /architect/e-business HTTP/1.1"'},
#  {'host': '61.48.202.41',
#   'name': 'walsh4800',
#   'time': '[21/Jun/2019:15:51:55 -0700]',
#   'request': '"POST /disintermediate HTTP/1.0"'},
#  {'host': '155.35.201.177',
#   'name': 'eichmann8620',
#   'time': '[21/Jun/2019:15:51:57 -0700]',
#   'request': '"POST /morph HTTP/1.1"'},
#  {'host': '124.17.214.111',
#   'name': 'kuhn7507',
#   'time': '[21/Jun/2019:15:51:59 -0700]',
#   'request': '"GET /orchestrate/vertical/technologies HTTP/2.0"'},
#  {'host': '188.250.73.73',
#   'name': 'kohler6082',
#   'time': '[21/Jun/2019:15:52:07 -0700]',
#   'request': '"HEAD /mindshare/facilitate HTTP/1.0"'},
#  {'host': '208.116.224.152',
#   'name': 'gutkowski5880',
#   'time': '[21/Jun/2019:15:52:10 -0700]',
#   'request': '"DELETE /revolutionary/portals HTTP/2.0"'},
#  {'host': '191.79.84.144',
#   'name': 'barrows5745',
#   'time': '[21/Jun/2019:15:52:12 -0700]',
#   'request': '"PUT /cross-platform HTTP/1.0"'},
#  {'host': '63.4.200.214',
#   'name': 'glover3672',
#   'time': '[21/Jun/2019:15:52:15 -0700]',
#   'request': '"PUT /architectures/infrastructures HTTP/1.1"'},
#  {'host': '141.127.230.209',
#   'name': 'bode3507',
#   'time': '[21/Jun/2019:15:52:16 -0700]',
#   'request': '"PUT /e-services/next-generation/efficient/ubiquitous HTTP/1.0"'},
#  {'host': '24.212.111.42',
#   'name': 'reilly5235',
#   'time': '[21/Jun/2019:15:52:20 -0700]',
#   'request': '"GET /niches HTTP/1.0"'},
#  {'host': '210.159.24.173',
#   'name': 'jacobs7691',
#   'time': '[21/Jun/2019:15:52:21 -0700]',
#   'request': '"PATCH /portals HTTP/1.0"'},
#  {'host': '154.37.76.207',
#   'name': 'schowalter4620',
#   'time': '[21/Jun/2019:15:52:22 -0700]',
#   'request': '"PATCH /envisioneer HTTP/1.0"'},
#  {'host': '139.217.225.28',
#   'name': 'schaden7207',
#   'time': '[21/Jun/2019:15:52:23 -0700]',
#   'request': '"GET /magnetic/bricks-and-clicks HTTP/1.0"'},
#  {'host': '72.71.45.246',
#   'name': 'beier2969',
#   'time': '[21/Jun/2019:15:52:25 -0700]',
#   'request': '"PATCH /generate/productize/disintermediate HTTP/2.0"'},
#  {'host': '107.32.126.199',
#   'name': 'schmidt4514',
#   'time': '[21/Jun/2019:15:52:27 -0700]',
#   'request': '"GET /optimize HTTP/1.1"'},
#  {'host': '5.36.208.122',
#   'name': 'bayer5640',
#   'time': '[21/Jun/2019:15:52:28 -0700]',
#   'request': '"GET /repurpose/models HTTP/1.1"'},
#  {'host': '49.8.35.58',
#   'name': 'donnelly9040',
#   'time': '[21/Jun/2019:15:52:31 -0700]',
#   'request': '"GET /architectures/compelling/networks HTTP/1.1"'},
#  {'host': '120.69.200.153',
#   'name': 'pfannerstill2409',
#   'time': '[21/Jun/2019:15:52:32 -0700]',
#   'request': '"POST /extend/portals/clicks-and-mortar/matrix HTTP/1.0"'},
#  {'host': '225.216.200.227',
#   'name': 'bartell3136',
#   'time': '[21/Jun/2019:15:52:33 -0700]',
#   'request': '"POST /enable HTTP/1.1"'},
#  {'host': '113.118.36.178',
#   'name': 'abernathy3937',
#   'time': '[21/Jun/2019:15:52:36 -0700]',
#   'request': '"GET /expedite/web-readiness/cutting-edge HTTP/2.0"'},
#  {'host': '115.198.27.247',
#   'name': 'denesik1416',
#   'time': '[21/Jun/2019:15:52:38 -0700]',
#   'request': '"PATCH /incubate/rich HTTP/1.0"'},
#  {'host': '160.111.19.169',
#   'name': 'roob2215',
#   'time': '[21/Jun/2019:15:52:39 -0700]',
#   'request': '"POST /transform/magnetic/grow/interfaces HTTP/1.1"'},
#  {'host': '245.2.226.215',
#   'name': 'rau3028',
#   'time': '[21/Jun/2019:15:52:40 -0700]',
#   'request': '"PUT /integrate HTTP/2.0"'},
#  {'host': '100.34.101.236',
#   'name': 'cartwright2493',
#   'time': '[21/Jun/2019:15:52:41 -0700]',
#   'request': '"PUT /mesh/bleeding-edge/sexy HTTP/2.0"'},
#  {'host': '196.228.156.210',
#   'name': 'parisian7014',
#   'time': '[21/Jun/2019:15:52:43 -0700]',
#   'request': '"HEAD /synergize HTTP/1.0"'},
#  {'host': '107.121.136.255',
#   'name': 'wolff3688',
#   'time': '[21/Jun/2019:15:52:44 -0700]',
#   'request': '"POST /portals HTTP/1.0"'},
#  {'host': '102.74.238.85',
#   'name': 'bosco8918',
#   'time': '[21/Jun/2019:15:52:49 -0700]',
#   'request': '"POST /viral/infomediaries/magnetic HTTP/1.0"'},
#  {'host': '234.26.87.233',
#   'name': 'stehr6393',
#   'time': '[21/Jun/2019:15:52:54 -0700]',
#   'request': '"DELETE /value-added/incubate/morph HTTP/1.0"'},
#  {'host': '157.237.224.179',
#   'name': 'wintheiser5662',
#   'time': '[21/Jun/2019:15:52:55 -0700]',
#   'request': '"POST /benchmark/generate/streamline/paradigms HTTP/1.0"'},
#  {'host': '195.195.194.123',
#   'name': 'raynor1706',
#   'time': '[21/Jun/2019:15:52:56 -0700]',
#   'request': '"PUT /whiteboard/roi/transition HTTP/1.1"'},
#  {'host': '74.202.178.240',
#   'name': 'gaylord7396',
#   'time': '[21/Jun/2019:15:52:57 -0700]',
#   'request': '"HEAD /visionary/incubate HTTP/1.1"'},
#  {'host': '155.123.176.15',
#   'name': 'streich4473',
#   'time': '[21/Jun/2019:15:52:58 -0700]',
#   'request': '"GET /content/optimize/benchmark HTTP/1.0"'},
#  {'host': '189.254.43.43',
#   'name': 'swift6867',
#   'time': '[21/Jun/2019:15:53:00 -0700]',
#   'request': '"GET /architectures/recontextualize/morph/scale HTTP/1.0"'},
#  {'host': '20.80.28.12',
#   'name': 'hagenes4423',
#   'time': '[21/Jun/2019:15:53:01 -0700]',
#   'request': '"POST /harness HTTP/1.1"'},
#  {'host': '44.188.73.217',
#   'name': 'volkman6528',
#   'time': '[21/Jun/2019:15:53:02 -0700]',
#   'request': '"POST /clicks-and-mortar/user-centric HTTP/1.1"'},
#  {'host': '90.53.226.196',
#   'name': 'bogan1483',
#   'time': '[21/Jun/2019:15:53:04 -0700]',
#   'request': '"PATCH /b2b/portals HTTP/2.0"'},
#  {'host': '200.229.201.189',
#   'name': 'donnelly8614',
#   'time': '[21/Jun/2019:15:53:08 -0700]',
#   'request': '"GET /interfaces/unleash/impactful/reinvent HTTP/1.0"'},
#  {'host': '172.82.22.49',
#   'name': 'cummerata1461',
#   'time': '[21/Jun/2019:15:53:12 -0700]',
#   'request': '"GET /mindshare HTTP/1.1"'},
#  {'host': '189.55.69.57',
#   'name': 'huel9795',
#   'time': '[21/Jun/2019:15:53:15 -0700]',
#   'request': '"POST /interfaces/synthesize/methodologies HTTP/1.0"'},
#  {'host': '181.223.103.195',
#   'name': 'gerhold3770',
#   'time': '[21/Jun/2019:15:53:16 -0700]',
#   'request': '"PATCH /markets/disintermediate/orchestrate/mesh HTTP/1.1"'},
#  {'host': '119.228.175.191',
#   'name': 'mills5084',
#   'time': '[21/Jun/2019:15:53:17 -0700]',
#   'request': '"DELETE /robust HTTP/2.0"'},
#  {'host': '139.238.48.126',
#   'name': 'champlin2089',
#   'time': '[21/Jun/2019:15:53:18 -0700]',
#   'request': '"GET /frictionless/matrix/exploit HTTP/2.0"'},
#  {'host': '66.144.178.220',
#   'name': 'beatty7852',
#   'time': '[21/Jun/2019:15:53:23 -0700]',
#   'request': '"PATCH /front-end HTTP/1.1"'},
#  {'host': '70.117.216.192',
#   'name': 'schultz9259',
#   'time': '[21/Jun/2019:15:53:24 -0700]',
#   'request': '"DELETE /strategic HTTP/2.0"'},
#  {'host': '168.223.229.31',
#   'name': 'lindgren9821',
#   'time': '[21/Jun/2019:15:53:29 -0700]',
#   'request': '"HEAD /b2c/expedite/innovate HTTP/1.1"'},
#  {'host': '169.142.205.93',
#   'name': 'moore8388',
#   'time': '[21/Jun/2019:15:53:31 -0700]',
#   'request': '"HEAD /bricks-and-clicks HTTP/1.0"'},
#  {'host': '86.48.209.75',
#   'name': 'friesen4112',
#   'time': '[21/Jun/2019:15:53:32 -0700]',
#   'request': '"PATCH /turn-key HTTP/1.1"'},
#  {'host': '128.29.111.92',
#   'name': 'schiller1863',
#   'time': '[21/Jun/2019:15:53:34 -0700]',
#   'request': '"HEAD /transform/revolutionize HTTP/1.0"'},
#  {'host': '234.228.65.79',
#   'name': 'littel6195',
#   'time': '[21/Jun/2019:15:53:37 -0700]',
#   'request': '"PATCH /aggregate/frictionless HTTP/1.0"'},
#  {'host': '161.215.232.221',
#   'name': 'leffler5851',
#   'time': '[21/Jun/2019:15:53:39 -0700]',
#   'request': '"POST /incubate/integrate/evolve/dynamic HTTP/1.0"'},
#  {'host': '26.228.235.113',
#   'name': 'renner7608',
#   'time': '[21/Jun/2019:15:53:41 -0700]',
#   'request': '"GET /intuitive HTTP/1.0"'},
#  {'host': '52.245.137.48',
#   'name': 'torp1455',
#   'time': '[21/Jun/2019:15:53:42 -0700]',
#   'request': '"PUT /customized/front-end/compelling HTTP/2.0"'},
#  {'host': '242.204.24.88',
#   'name': 'flatley5085',
#   'time': '[21/Jun/2019:15:53:43 -0700]',
#   'request': '"GET /ubiquitous/out-of-the-box/embrace/roi HTTP/2.0"'},
#  {'host': '152.235.217.21',
#   'name': 'adams1613',
#   'time': '[21/Jun/2019:15:53:46 -0700]',
#   'request': '"GET /infrastructures/vortals/proactive/interactive HTTP/2.0"'},
#  {'host': '227.249.188.131',
#   'name': 'kovacek4008',
#   'time': '[21/Jun/2019:15:53:49 -0700]',
#   'request': '"GET /action-items/strategize/visionary/channels HTTP/1.1"'},
#  {'host': '111.215.175.31',
#   'name': 'roob7404',
#   'time': '[21/Jun/2019:15:53:50 -0700]',
#   'request': '"PUT /envisioneer HTTP/2.0"'},
#  {'host': '34.37.57.246',
#   'name': 'pacocha5980',
#   'time': '[21/Jun/2019:15:53:54 -0700]',
#   'request': '"PUT /architectures/recontextualize HTTP/1.0"'},
#  {'host': '177.181.89.94',
#   'name': 'friesen8390',
#   'time': '[21/Jun/2019:15:53:55 -0700]',
#   'request': '"DELETE /leverage/enhance HTTP/2.0"'},
#  {'host': '77.228.64.198',
#   'name': 'steuber9732',
#   'time': '[21/Jun/2019:15:53:57 -0700]',
#   'request': '"PATCH /end-to-end/vortals/applications HTTP/1.0"'},
#  {'host': '126.202.3.228',
#   'name': 'cassin9066',
#   'time': '[21/Jun/2019:15:54:01 -0700]',
#   'request': '"PATCH /brand/ubiquitous/scale HTTP/1.0"'},
#  {'host': '134.146.54.60',
#   'name': 'feil3529',
#   'time': '[21/Jun/2019:15:54:02 -0700]',
#   'request': '"DELETE /eyeballs/streamline/holistic HTTP/1.0"'},
#  {'host': '19.245.212.207',
#   'name': 'walsh8648',
#   'time': '[21/Jun/2019:15:54:03 -0700]',
#   'request': '"GET /recontextualize HTTP/1.1"'},
#  {'host': '98.143.107.61',
#   'name': 'reilly5813',
#   'time': '[21/Jun/2019:15:54:04 -0700]',
#   'request': '"HEAD /channels HTTP/1.1"'},
#  {'host': '235.231.96.133',
#   'name': 'feest6743',
#   'time': '[21/Jun/2019:15:54:05 -0700]',
#   'request': '"PATCH /24%2f365 HTTP/1.0"'},
#  {'host': '124.199.28.96',
#   'name': 'conroy1743',
#   'time': '[21/Jun/2019:15:54:09 -0700]',
#   'request': '"PATCH /generate/global HTTP/2.0"'},
#  {'host': '249.3.215.17',
#   'name': 'daugherty5037',
#   'time': '[21/Jun/2019:15:54:10 -0700]',
#   'request': '"GET /cross-platform/syndicate/unleash HTTP/2.0"'},
#  {'host': '213.54.223.189',
#   'name': 'batz7344',
#   'time': '[21/Jun/2019:15:54:11 -0700]',
#   'request': '"DELETE /maximize/extensible/open-source/facilitate HTTP/1.0"'},
#  {'host': '235.109.203.135',
#   'name': 'mitchell2009',
#   'time': '[21/Jun/2019:15:54:12 -0700]',
#   'request': '"POST /holistic HTTP/2.0"'},
#  {'host': '173.176.32.197',
#   'name': 'reilly4254',
#   'time': '[21/Jun/2019:15:54:13 -0700]',
#   'request': '"HEAD /experiences/e-business/grow/matrix HTTP/1.0"'},
#  {'host': '20.180.86.45',
#   'name': 'ritchie8554',
#   'time': '[21/Jun/2019:15:54:16 -0700]',
#   'request': '"PUT /holistic HTTP/1.1"'},
#  {'host': '125.180.138.91',
#   'name': 'corkery6385',
#   'time': '[21/Jun/2019:15:54:18 -0700]',
#   'request': '"HEAD /innovate/sticky/distributed HTTP/1.1"'},
#  {'host': '226.178.150.114',
#   'name': 'donnelly1349',
#   'time': '[21/Jun/2019:15:54:21 -0700]',
#   'request': '"PATCH /productize/expedite HTTP/1.1"'},
#  {'host': '185.16.173.169',
#   'name': 'mcdermott9999',
#   'time': '[21/Jun/2019:15:54:23 -0700]',
#   'request': '"PUT /maximize/bricks-and-clicks HTTP/2.0"'},
#  {'host': '82.165.247.195',
#   'name': 'lueilwitz2757',
#   'time': '[21/Jun/2019:15:54:24 -0700]',
#   'request': '"DELETE /facilitate/bricks-and-clicks/models HTTP/1.1"'},
#  {'host': '44.53.132.30',
#   'name': 'beatty4977',
#   'time': '[21/Jun/2019:15:54:25 -0700]',
#   'request': '"HEAD /cross-platform HTTP/2.0"'},
#  {'host': '203.86.100.44',
#   'name': 'dickens5496',
#   'time': '[21/Jun/2019:15:54:26 -0700]',
#   'request': '"PATCH /integrated/distributed/streamline HTTP/2.0"'},
#  {'host': '33.223.33.138',
#   'name': 'kling6394',
#   'time': '[21/Jun/2019:15:54:27 -0700]',
#   'request': '"PUT /back-end/initiatives/monetize/repurpose HTTP/2.0"'},
#  {'host': '143.90.188.100',
#   'name': 'lebsack6923',
#   'time': '[21/Jun/2019:15:54:31 -0700]',
#   'request': '"PATCH /target/back-end HTTP/1.1"'},
#  {'host': '185.89.247.140',
#   'name': 'leannon8734',
#   'time': '[21/Jun/2019:15:54:34 -0700]',
#   'request': '"GET /deliverables HTTP/2.0"'},
#  {'host': '219.142.205.21',
#   'name': 'oreilly3853',
#   'time': '[21/Jun/2019:15:54:38 -0700]',
#   'request': '"PUT /compelling HTTP/1.0"'},
#  {'host': '213.119.21.213',
#   'name': 'thompson6913',
#   'time': '[21/Jun/2019:15:54:40 -0700]',
#   'request': '"PUT /bandwidth/holistic HTTP/2.0"'},
#  {'host': '159.75.120.41',
#   'name': 'muller7604',
#   'time': '[21/Jun/2019:15:54:42 -0700]',
#   'request': '"GET /incentivize HTTP/2.0"'},
#  {'host': '2.23.245.201',
#   'name': 'swaniawski1648',
#   'time': '[21/Jun/2019:15:54:44 -0700]',
#   'request': '"DELETE /matrix/leverage/infomediaries/viral HTTP/1.0"'},
#  {'host': '222.90.182.151',
#   'name': 'braun1134',
#   'time': '[21/Jun/2019:15:54:45 -0700]',
#   'request': '"PATCH /transition HTTP/2.0"'},
#  {'host': '173.229.51.155',
#   'name': 'fahey6288',
#   'time': '[21/Jun/2019:15:54:49 -0700]',
#   'request': '"PUT /grow HTTP/1.0"'},
#  {'host': '181.166.48.160',
#   'name': 'jacobi1228',
#   'time': '[21/Jun/2019:15:54:50 -0700]',
#   'request': '"HEAD /channels/enhance/magnetic/plug-and-play HTTP/1.1"'},
#  {'host': '94.55.84.135',
#   'name': 'walker7116',
#   'time': '[21/Jun/2019:15:54:52 -0700]',
#   'request': '"DELETE /engineer/one-to-one/e-services HTTP/2.0"'},
#  {'host': '123.179.141.133',
#   'name': 'hammes4241',
#   'time': '[21/Jun/2019:15:54:55 -0700]',
#   'request': '"GET /unleash HTTP/1.1"'},
#  {'host': '67.233.253.149',
#   'name': 'dubuque4293',
#   'time': '[21/Jun/2019:15:54:59 -0700]',
#   'request': '"PATCH /synthesize HTTP/1.1"'},
#  {'host': '235.52.222.116',
#   'name': 'williamson4151',
#   'time': '[21/Jun/2019:15:55:00 -0700]',
#   'request': '"HEAD /initiatives HTTP/1.1"'},
#  {'host': '162.104.12.102',
#   'name': 'heidenreich1792',
#   'time': '[21/Jun/2019:15:55:05 -0700]',
#   'request': '"PUT /e-enable HTTP/2.0"'},
#  {'host': '91.164.20.118',
#   'name': 'leffler4523',
#   'time': '[21/Jun/2019:15:55:07 -0700]',
#   'request': '"PUT /grow/granular/optimize HTTP/1.0"'},
#  {'host': '43.204.214.54',
#   'name': 'fritsch5442',
#   'time': '[21/Jun/2019:15:55:10 -0700]',
#   'request': '"HEAD /innovate/viral HTTP/1.0"'},
#  {'host': '136.140.99.71',
#   'name': 'jast3185',
#   'time': '[21/Jun/2019:15:55:12 -0700]',
#   'request': '"HEAD /systems/rich/best-of-breed HTTP/1.1"'},
#  {'host': '59.40.69.33',
#   'name': 'kerluke1992',
#   'time': '[21/Jun/2019:15:55:14 -0700]',
#   'request': '"PUT /virtual/markets/compelling HTTP/2.0"'},
#  {'host': '37.37.184.46',
#   'name': 'west3231',
#   'time': '[21/Jun/2019:15:55:16 -0700]',
#   'request': '"HEAD /action-items/bricks-and-clicks/drive/envisioneer HTTP/1.1"'},
#  {'host': '202.152.160.70',
#   'name': 'ankunding8652',
#   'time': '[21/Jun/2019:15:55:20 -0700]',
#   'request': '"DELETE /e-tailers/granular/value-added HTTP/2.0"'},
#  {'host': '121.11.126.214',
#   'name': 'barton5952',
#   'time': '[21/Jun/2019:15:55:24 -0700]',
#   'request': '"DELETE /user-centric/leading-edge HTTP/2.0"'},
#  {'host': '116.66.227.58',
#   'name': 'boyle7076',
#   'time': '[21/Jun/2019:15:55:26 -0700]',
#   'request': '"PATCH /mission-critical/action-items/niches/strategize HTTP/1.0"'},
#  {'host': '139.116.88.147',
#   'name': 'haag9280',
#   'time': '[21/Jun/2019:15:55:28 -0700]',
#   'request': '"HEAD /transparent/redefine/methodologies/exploit HTTP/1.0"'},
#  {'host': '183.117.169.253',
#   'name': 'morar4269',
#   'time': '[21/Jun/2019:15:55:30 -0700]',
#   'request': '"HEAD /architectures/user-centric HTTP/1.1"'},
#  {'host': '60.155.203.130',
#   'name': 'vonrueden7712',
#   'time': '[21/Jun/2019:15:55:31 -0700]',
#   'request': '"DELETE /metrics/infomediaries/enterprise/b2b HTTP/1.0"'},
#  {'host': '173.140.74.179',
#   'name': 'rippin3809',
#   'time': '[21/Jun/2019:15:55:32 -0700]',
#   'request': '"POST /engage HTTP/2.0"'},
#  {'host': '221.208.57.139',
#   'name': 'bayer1705',
#   'time': '[21/Jun/2019:15:55:33 -0700]',
#   'request': '"HEAD /reintermediate/target HTTP/1.1"'},
#  {'host': '149.212.98.132',
#   'name': 'kerluke1906',
#   'time': '[21/Jun/2019:15:55:35 -0700]',
#   'request': '"HEAD /reintermediate HTTP/1.1"'},
#  {'host': '79.233.211.50',
#   'name': 'lowe5988',
#   'time': '[21/Jun/2019:15:55:36 -0700]',
#   'request': '"GET /vortals/world-class/next-generation/maximize HTTP/2.0"'},
#  {'host': '208.84.72.231',
# ...
#   'request': '"PUT /collaborative/holistic/recontextualize HTTP/2.0"'},
#  {'host': '194.203.51.120',
#   'name': 'boyer5523',
#   'time': '[21/Jun/2019:15:58:27 -0700]',
#   'request': '"PATCH /frictionless HTTP/1.0"'},
#  {'host': '71.121.222.200',
#   'name': 'russel8326',
#   'time': '[21/Jun/2019:15:58:28 -0700]',
#   'request': '"PUT /deliver/schemas HTTP/1.0"'},
#  {'host': '171.218.147.47',
#   'name': 'white9937',
#   'time': '[21/Jun/2019:15:58:30 -0700]',
#   'request': '"HEAD /cutting-edge/grow HTTP/1.0"'},
#  {'host': '122.81.125.121',
#   'name': 'bednar2405',
#   'time': '[21/Jun/2019:15:58:37 -0700]',
#   'request': '"POST /partnerships/experiences HTTP/1.0"'},
#  {'host': '192.202.173.198',
#   'name': 'yost8436',
#   'time': '[21/Jun/2019:15:58:42 -0700]',
#   'request': '"GET /mindshare/aggregate/deliverables/global HTTP/2.0"'},
#  {'host': '189.226.103.3',
#   'name': 'kemmer7294',
#   'time': '[21/Jun/2019:15:58:45 -0700]',
#   'request': '"PUT /sexy/transition/enterprise HTTP/1.1"'},
#  {'host': '135.82.100.60',
#   'name': 'wuckert5235',
#   'time': '[21/Jun/2019:15:58:46 -0700]',
#   'request': '"HEAD /leading-edge/solutions/robust HTTP/1.1"'},
#  {'host': '243.151.163.69',
#   'name': 'lueilwitz6619',
#   'time': '[21/Jun/2019:15:58:47 -0700]',
#   'request': '"POST /experiences/value-added HTTP/1.0"'},
#  {'host': '167.55.97.60',
#   'name': 'terry5334',
#   'time': '[21/Jun/2019:15:58:48 -0700]',
#   'request': '"PATCH /monetize/proactive HTTP/1.1"'},
#  {'host': '159.65.201.34',
#   'name': 'bergnaum8203',
#   'time': '[21/Jun/2019:15:58:50 -0700]',
#   'request': '"PUT /intuitive/revolutionize/experiences HTTP/2.0"'},
#  {'host': '184.245.98.205',
#   'name': 'oreilly1191',
#   'time': '[21/Jun/2019:15:58:52 -0700]',
#   'request': '"GET /users/real-time HTTP/2.0"'},
#  {'host': '68.168.186.14',
#   'name': 'weissnat9339',
#   'time': '[21/Jun/2019:15:58:55 -0700]',
#   'request': '"DELETE /schemas/user-centric HTTP/2.0"'},
#  {'host': '8.117.240.56',
#   'name': 'pouros2120',
#   'time': '[21/Jun/2019:15:58:58 -0700]',
#   'request': '"GET /reintermediate HTTP/1.0"'},
#  {'host': '207.81.12.169',
#   'name': 'jerde5243',
#   'time': '[21/Jun/2019:15:58:59 -0700]',
#   'request': '"PUT /architectures/extend HTTP/2.0"'},
#  {'host': '229.128.199.145',
#   'name': 'kris7724',
#   'time': '[21/Jun/2019:15:59:00 -0700]',
#   'request': '"POST /reinvent HTTP/1.1"'},
#  {'host': '226.153.34.134',
#   'name': 'boyer6744',
#   'time': '[21/Jun/2019:15:59:01 -0700]',
#   'request': '"PUT /robust/incubate HTTP/1.1"'},
#  {'host': '84.168.91.70',
#   'name': 'wilderman5041',
#   'time': '[21/Jun/2019:15:59:02 -0700]',
#   'request': '"DELETE /expedite/rich HTTP/2.0"'},
#  {'host': '2.241.18.210',
#   'name': 'cassin3470',
#   'time': '[21/Jun/2019:15:59:03 -0700]',
#   'request': '"DELETE /mission-critical/technologies HTTP/1.0"'},
#  {'host': '240.71.224.216',
#   'name': 'weimann5347',
#   'time': '[21/Jun/2019:15:59:07 -0700]',
#   'request': '"HEAD /matrix/integrated/e-commerce HTTP/1.1"'},
#  {'host': '110.45.207.230',
#   'name': 'boyer3703',
#   'time': '[21/Jun/2019:15:59:08 -0700]',
#   'request': '"GET /strategize/sticky/portals/applications HTTP/1.1"'},
#  {'host': '67.17.225.243',
#   'name': 'mann4196',
#   'time': '[21/Jun/2019:15:59:17 -0700]',
#   'request': '"DELETE /initiatives/synergize/enable HTTP/1.1"'},
#  {'host': '102.253.250.180',
#   'name': 'marks6484',
#   'time': '[21/Jun/2019:15:59:20 -0700]',
#   'request': '"POST /portals/communities HTTP/1.1"'},
#  {'host': '188.55.154.154',
#   'name': 'kling2211',
#   'time': '[21/Jun/2019:15:59:21 -0700]',
#   'request': '"PUT /transparent/strategic/efficient HTTP/1.0"'},
#  {'host': '109.249.168.154',
#   'name': 'barrows4994',
#   'time': '[21/Jun/2019:15:59:22 -0700]',
#   'request': '"POST /ubiquitous/supply-chains/utilize/facilitate HTTP/2.0"'},
#  {'host': '71.206.76.249',
#   'name': 'schimmel7061',
#   'time': '[21/Jun/2019:15:59:23 -0700]',
#   'request': '"POST /24%2f7/mindshare HTTP/1.0"'},
#  {'host': '157.114.250.181',
#   'name': 'witting4267',
#   'time': '[21/Jun/2019:15:59:27 -0700]',
#   'request': '"PUT /web-readiness/embrace HTTP/1.1"'},
#  {'host': '175.192.140.87',
#   'name': 'abernathy8063',
#   'time': '[21/Jun/2019:15:59:29 -0700]',
#   'request': '"GET /experiences/one-to-one HTTP/1.1"'},
#  {'host': '53.179.178.201',
#   'name': 'pagac4236',
#   'time': '[21/Jun/2019:15:59:30 -0700]',
#   'request': '"PATCH /one-to-one/b2b HTTP/1.1"'},
#  {'host': '204.6.151.116',
#   'name': 'feeney1779',
#   'time': '[21/Jun/2019:15:59:32 -0700]',
#   'request': '"PATCH /dot-com HTTP/1.1"'},
#  {'host': '128.137.44.120',
#   'name': 'gulgowski4789',
#   'time': '[21/Jun/2019:15:59:33 -0700]',
#   'request': '"POST /envisioneer/convergence HTTP/1.1"'},
#  {'host': '160.83.97.225',
#   'name': 'gaylord3825',
#   'time': '[21/Jun/2019:15:59:38 -0700]',
#   'request': '"DELETE /infomediaries HTTP/1.1"'},
#  {'host': '57.250.82.249',
#   'name': 'abshire9350',
#   'time': '[21/Jun/2019:15:59:40 -0700]',
#   'request': '"HEAD /web-enabled/mindshare/open-source HTTP/1.0"'},
#  {'host': '201.74.167.219',
#   'name': 'dickinson7510',
#   'time': '[21/Jun/2019:15:59:43 -0700]',
#   'request': '"DELETE /functionalities/b2b HTTP/1.1"'},
#  {'host': '247.66.231.101',
#   'name': 'schroeder6056',
#   'time': '[21/Jun/2019:15:59:44 -0700]',
#   'request': '"PATCH /viral/global/e-markets/synergistic HTTP/1.0"'},
#  {'host': '187.151.112.252',
#   'name': 'cronin9150',
#   'time': '[21/Jun/2019:15:59:46 -0700]',
#   'request': '"POST /holistic/plug-and-play HTTP/1.1"'},
#  {'host': '184.49.40.239',
#   'name': 'cronin7061',
#   'time': '[21/Jun/2019:15:59:48 -0700]',
#   'request': '"POST /turn-key/maximize/vertical/harness HTTP/1.1"'},
#  {'host': '161.40.136.30',
#   'name': 'hackett2278',
#   'time': '[21/Jun/2019:15:59:50 -0700]',
#   'request': '"HEAD /bandwidth/syndicate/extend HTTP/2.0"'},
#  {'host': '73.245.186.113',
#   'name': 'johnston8800',
#   'time': '[21/Jun/2019:15:59:53 -0700]',
#   'request': '"HEAD /technologies/monetize/visualize HTTP/1.1"'},
#  {'host': '251.66.234.159',
#   'name': 'casper4259',
#   'time': '[21/Jun/2019:15:59:55 -0700]',
#   'request': '"PATCH /envisioneer/web+services/e-tailers HTTP/1.1"'},
#  {'host': '69.168.5.186',
#   'name': 'hudson3060',
#   'time': '[21/Jun/2019:15:59:58 -0700]',
#   'request': '"GET /seamless/applications HTTP/1.1"'},
#  {'host': '178.51.230.221',
#   'name': 'beer4262',
#   'time': '[21/Jun/2019:15:59:59 -0700]',
#   'request': '"PUT /portals HTTP/1.0"'},
#  {'host': '167.14.84.150',
#   'name': 'corkery7009',
#   'time': '[21/Jun/2019:16:00:02 -0700]',
#   'request': '"PATCH /cross-platform/engage HTTP/2.0"'},
#  {'host': '108.73.111.91',
#   'name': 'rolfson4266',
#   'time': '[21/Jun/2019:16:00:03 -0700]',
#   'request': '"POST /sexy/relationships/envisioneer HTTP/1.1"'},
#  {'host': '255.34.248.138',
#   'name': 'lehner7598',
#   'time': '[21/Jun/2019:16:00:04 -0700]',
#   'request': '"PUT /visionary/exploit/strategize HTTP/1.1"'},
#  {'host': '175.248.234.53',
#   'name': 'connelly6139',
#   'time': '[21/Jun/2019:16:00:05 -0700]',
#   'request': '"GET /end-to-end/initiatives HTTP/1.0"'},
#  {'host': '114.121.4.5',
#   'name': 'dickinson1321',
#   'time': '[21/Jun/2019:16:00:08 -0700]',
#   'request': '"HEAD /ubiquitous/strategic/innovative HTTP/2.0"'},
#  {'host': '87.120.190.31',
#   'name': 'mraz2398',
#   'time': '[21/Jun/2019:16:00:10 -0700]',
#   'request': '"PUT /incentivize/deliver/frictionless HTTP/1.0"'},
#  {'host': '123.55.15.237',
#   'name': 'stracke7667',
#   'time': '[21/Jun/2019:16:00:11 -0700]',
#   'request': '"POST /bricks-and-clicks/wireless/iterate HTTP/2.0"'},
#  {'host': '76.179.226.223',
#   'name': 'gleichner8645',
#   'time': '[21/Jun/2019:16:00:12 -0700]',
#   'request': '"PATCH /incubate/enhance/enhance/plug-and-play HTTP/1.1"'},
#  {'host': '18.251.182.128',
#   'name': 'huels1658',
#   'time': '[21/Jun/2019:16:00:13 -0700]',
#   'request': '"PATCH /benchmark/seize/end-to-end HTTP/1.0"'},
#  {'host': '130.4.238.6',
#   'name': 'thompson4128',
#   'time': '[21/Jun/2019:16:00:14 -0700]',
#   'request': '"PUT /whiteboard HTTP/1.1"'},
#  {'host': '30.235.201.100',
#   'name': 'labadie1675',
#   'time': '[21/Jun/2019:16:00:15 -0700]',
#   'request': '"HEAD /sexy/seamless/channels HTTP/1.0"'},
#  {'host': '172.200.189.116',
#   'name': 'moen2257',
#   'time': '[21/Jun/2019:16:00:16 -0700]',
#   'request': '"PUT /visionary HTTP/2.0"'},
#  {'host': '129.243.225.31',
#   'name': 'gerlach4189',
#   'time': '[21/Jun/2019:16:00:17 -0700]',
#   'request': '"HEAD /turn-key/enhance/deploy HTTP/1.1"'},
#  {'host': '234.151.43.108',
#   'name': 'gutkowski1749',
#   'time': '[21/Jun/2019:16:00:18 -0700]',
#   'request': '"POST /experiences/cultivate/communities HTTP/2.0"'},
#  {'host': '128.230.157.15',
#   'name': 'koch1729',
#   'time': '[21/Jun/2019:16:00:19 -0700]',
#   'request': '"POST /revolutionize HTTP/1.1"'},
#  {'host': '147.89.158.20',
#   'name': 'sawayn3251',
#   'time': '[21/Jun/2019:16:00:22 -0700]',
#   'request': '"PUT /clicks-and-mortar/b2c/e-enable HTTP/1.1"'},
#  {'host': '98.221.131.91',
#   'name': 'heaney8725',
#   'time': '[21/Jun/2019:16:00:24 -0700]',
#   'request': '"POST /seamless/scale HTTP/1.0"'},
#  {'host': '178.205.28.42',
#   'name': 'koss1578',
#   'time': '[21/Jun/2019:16:00:26 -0700]',
#   'request': '"DELETE /convergence HTTP/2.0"'},
#  {'host': '203.6.73.103',
#   'name': 'kerluke4964',
#   'time': '[21/Jun/2019:16:00:31 -0700]',
#   'request': '"DELETE /collaborative/magnetic HTTP/1.1"'},
#  {'host': '30.200.244.157',
#   'name': 'zieme4477',
#   'time': '[21/Jun/2019:16:00:32 -0700]',
#   'request': '"HEAD /virtual/sticky/leading-edge/reintermediate HTTP/2.0"'},
#  {'host': '104.242.54.162',
#   'name': 'weber7878',
#   'time': '[21/Jun/2019:16:00:35 -0700]',
#   'request': '"HEAD /dynamic/models/productize HTTP/1.0"'},
#  {'host': '210.119.75.247',
#   'name': 'lemke8387',
#   'time': '[21/Jun/2019:16:00:36 -0700]',
#   'request': '"PATCH /partnerships/deploy/impactful/infomediaries HTTP/1.1"'},
#  {'host': '151.70.203.139',
#   'name': 'reinger7161',
#   'time': '[21/Jun/2019:16:00:38 -0700]',
#   'request': '"DELETE /strategic/repurpose/infrastructures HTTP/2.0"'},
#  {'host': '146.50.234.201',
#   'name': 'glover8440',
#   'time': '[21/Jun/2019:16:00:40 -0700]',
#   'request': '"PUT /partnerships/networks/frictionless HTTP/1.0"'},
#  {'host': '195.58.191.112',
#   'name': 'boyer8373',
#   'time': '[21/Jun/2019:16:00:41 -0700]',
#   'request': '"DELETE /integrate HTTP/2.0"'},
#  {'host': '24.7.110.141',
#   'name': 'hilpert8913',
#   'time': '[21/Jun/2019:16:00:43 -0700]',
#   'request': '"GET /syndicate/bleeding-edge/implement/24%2f365 HTTP/1.0"'},
#  {'host': '189.49.24.146',
#   'name': 'wunsch1258',
#   'time': '[21/Jun/2019:16:00:46 -0700]',
#   'request': '"GET /users/extend/expedite/channels HTTP/1.1"'},
#  {'host': '59.66.248.21',
#   'name': 'kutch7667',
#   'time': '[21/Jun/2019:16:00:51 -0700]',
#   'request': '"GET /expedite/turn-key/exploit HTTP/1.1"'},
#  {'host': '218.91.27.210',
#   'name': 'turcotte8545',
#   'time': '[21/Jun/2019:16:00:53 -0700]',
#   'request': '"POST /redefine HTTP/1.0"'},
#  {'host': '91.39.192.43',
#   'name': 'thompson4010',
#   'time': '[21/Jun/2019:16:01:01 -0700]',
#   'request': '"PATCH /e-tailers HTTP/1.0"'},
#  {'host': '197.150.196.204',
#   'name': 'thiel4558',
#   'time': '[21/Jun/2019:16:01:05 -0700]',
#   'request': '"PATCH /compelling HTTP/2.0"'},
#  {'host': '199.10.120.170',
#   'name': 'murazik3963',
#   'time': '[21/Jun/2019:16:01:06 -0700]',
#   'request': '"DELETE /frictionless/magnetic/e-markets/visionary HTTP/1.0"'},
#  {'host': '21.65.184.146',
#   'name': 'lockman2593',
#   'time': '[21/Jun/2019:16:01:07 -0700]',
#   'request': '"DELETE /sexy HTTP/1.1"'},
#  {'host': '36.191.173.200',
#   'name': 'metz3511',
#   'time': '[21/Jun/2019:16:01:08 -0700]',
#   'request': '"POST /revolutionary/seamless/disintermediate/generate HTTP/1.0"'},
#  {'host': '95.253.30.75',
#   'name': 'herzog9094',
#   'time': '[21/Jun/2019:16:01:11 -0700]',
#   'request': '"POST /mindshare HTTP/1.1"'},
#  {'host': '149.70.38.192',
#   'name': 'gorczany7585',
#   'time': '[21/Jun/2019:16:01:13 -0700]',
#   'request': '"POST /real-time/utilize/relationships/leverage HTTP/1.0"'},
#  {'host': '109.208.102.251',
#   'name': 'schroeder2270',
#   'time': '[21/Jun/2019:16:01:14 -0700]',
#   'request': '"DELETE /leverage HTTP/2.0"'},
#  {'host': '204.236.10.235',
#   'name': 'rodriguez5244',
#   'time': '[21/Jun/2019:16:01:17 -0700]',
#   'request': '"GET /synergies/expedite/deploy HTTP/1.0"'},
#  {'host': '158.49.98.6',
#   'name': 'breitenberg4724',
#   'time': '[21/Jun/2019:16:01:18 -0700]',
#   'request': '"DELETE /global/channels/relationships HTTP/1.1"'},
#  {'host': '156.192.201.86',
#   'name': 'connelly5114',
#   'time': '[21/Jun/2019:16:01:21 -0700]',
#   'request': '"PATCH /whiteboard/optimize HTTP/2.0"'},
#  {'host': '214.115.87.186',
#   'name': 'gorczany2750',
#   'time': '[21/Jun/2019:16:01:23 -0700]',
#   'request': '"GET /plug-and-play/productize/deliverables HTTP/1.1"'},
#  {'host': '69.218.146.39',
#   'name': 'kohler8056',
#   'time': '[21/Jun/2019:16:01:26 -0700]',
#   'request': '"HEAD /systems HTTP/1.0"'},
#  {'host': '70.68.196.179',
#   'name': 'cartwright5970',
#   'time': '[21/Jun/2019:16:01:28 -0700]',
#   'request': '"POST /b2c/cross-media HTTP/1.0"'},
#  {'host': '126.63.247.146',
#   'name': 'leuschke4130',
#   'time': '[21/Jun/2019:16:01:29 -0700]',
#   'request': '"GET /collaborative HTTP/2.0"'},
#  {'host': '196.88.105.189',
#   'name': 'lynch1110',
#   'time': '[21/Jun/2019:16:01:31 -0700]',
#   'request': '"POST /convergence/web-enabled/turn-key HTTP/1.1"'},
#  {'host': '173.100.77.100',
#   'name': 'goodwin1310',
#   'time': '[21/Jun/2019:16:01:32 -0700]',
#   'request': '"HEAD /integrate/visualize/implement/infomediaries HTTP/1.0"'},
#  {'host': '17.106.152.183',
#   'name': 'thiel8831',
#   'time': '[21/Jun/2019:16:01:33 -0700]',
#   'request': '"POST /architect/supply-chains/rich/cultivate HTTP/1.0"'},
#  {'host': '193.252.191.251',
#   'name': 'roob3235',
#   'time': '[21/Jun/2019:16:01:36 -0700]',
#   'request': '"POST /extensible HTTP/1.1"'},
#  {'host': '205.98.120.209',
#   'name': 'trantow6874',
#   'time': '[21/Jun/2019:16:01:39 -0700]',
#   'request': '"PUT /front-end/world-class/partnerships/schemas HTTP/1.0"'},
#  {'host': '148.196.48.243',
#   'name': 'ondricka6863',
#   'time': '[21/Jun/2019:16:01:40 -0700]',
#   'request': '"GET /best-of-breed/reinvent HTTP/1.1"'},
#  {'host': '130.229.174.187',
#   'name': 'hackett3055',
#   'time': '[21/Jun/2019:16:01:41 -0700]',
#   'request': '"GET /sticky/deliver HTTP/2.0"'},
#  {'host': '105.162.151.140',
#   'name': 'herzog1680',
#   'time': '[21/Jun/2019:16:01:44 -0700]',
#   'request': '"POST /24%2f365/next-generation HTTP/1.1"'},
#  {'host': '64.14.181.183',
#   'name': 'gleichner2813',
#   'time': '[21/Jun/2019:16:01:45 -0700]',
#   'request': '"GET /innovate/mesh HTTP/2.0"'},
#  {'host': '183.150.10.151',
#   'name': 'hammes8029',
#   'time': '[21/Jun/2019:16:01:46 -0700]',
#   'request': '"HEAD /clicks-and-mortar HTTP/1.0"'},
#  {'host': '137.138.99.222',
#   'name': 'doyle8430',
#   'time': '[21/Jun/2019:16:01:47 -0700]',
#   'request': '"DELETE /e-commerce/brand/extend/innovative HTTP/2.0"'},
#  {'host': '31.191.115.136',
#   'name': 'parker1133',
#   'time': '[21/Jun/2019:16:01:48 -0700]',
#   'request': '"PATCH /visualize/clicks-and-mortar/facilitate HTTP/1.0"'},
#  {'host': '24.29.142.39',
#   'name': 'koelpin1900',
#   'time': '[21/Jun/2019:16:01:51 -0700]',
#   'request': '"DELETE /monetize/user-centric HTTP/1.1"'},
#  {'host': '56.36.101.14',
#   'name': 'davis6497',
#   'time': '[21/Jun/2019:16:01:52 -0700]',
#   'request': '"GET /cutting-edge/matrix/productize/web+services HTTP/1.1"'},
#  {'host': '98.140.180.244',
#   'name': 'harber4797',
#   'time': '[21/Jun/2019:16:01:53 -0700]',
#   'request': '"POST /seize/b2b/synergistic HTTP/2.0"'},
#  {'host': '54.92.231.149',
#   'name': 'ziemann5634',
#   'time': '[21/Jun/2019:16:01:54 -0700]',
#   'request': '"GET /revolutionize/matrix HTTP/2.0"'},
#  {'host': '176.68.62.252',
#   'name': 'turner3261',
#   'time': '[21/Jun/2019:16:02:00 -0700]',
#   'request': '"GET /viral HTTP/1.1"'},
#  {'host': '35.86.149.61',
#   'name': 'zemlak6334',
#   'time': '[21/Jun/2019:16:02:01 -0700]',
#   'request': '"HEAD /incentivize HTTP/2.0"'},
#  {'host': '30.95.91.251',
#   'name': 'larson8319',
#   'time': '[21/Jun/2019:16:02:02 -0700]',
#   'request': '"PUT /one-to-one/whiteboard HTTP/1.0"'}]

# %%
assert len(logs()) == 979
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 assert len(logs()) == 979
#
# AssertionError:
